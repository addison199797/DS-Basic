# %% [markdown]
# # Week One Homework

# %% [markdown]
# 使用学习的Python指令和数据分析方法对IRIS data进行分析,包含:\
# (1)各特征缺失值查找,\
# (2)异常值查找\
# (3)各特征描述:平均值,标准差,最大/最小值等\
# (4)通过画图展示各特征分布密度函数(pdf)\
# (5)各特征间相关性\
#
# 特征指每列数据,异常值查找常用的有几种方法:MAD,标准差法和百分位数法,选
# 择其中一种即可。分布密度函数展示有多种方法:直方图,调用kde函数等,选择一种即可。

# %%
#Import Library

import pandas as pd
import numpy as np

# %%
from io import StringIO
data = "col1,col2,col3\na,b,1\na,b,2\nc,d,3"
pd.read_csv(StringIO(data))
